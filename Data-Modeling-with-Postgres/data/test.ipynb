# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays WHERE artist_id != 'None' order by artist_id;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(datetime.datetime(2018, 11, 21, 21, 56, 47, 796000), '15', 'paid', 'SOZCTXZ12AB0182364', 'AR5KOSW1187FB35FF4', '818', 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')]

# %%
# %sql SELECT * FROM users ORDER BY last_name;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 96 rows affected.
# [('66', 'Kevin', 'Arellano', 'M', 'free'),
#  ('34', 'Evelin', 'Ayala', 'F', 'free'),
#  ('99', 'Ann', 'Banks', 'F', 'free'),
#  ('100', 'Adler', 'Barrera', 'M', 'free'),
#  ('42', 'Harper', 'Barrett', 'M', 'paid'),
#  ('91', 'Jayden', 'Bell', 'M', 'free'),
#  ('2', 'Jizelle', 'Benjamin', 'F', 'free'),
#  ('58', 'Emily', 'Benson', 'F', 'paid'),
#  ('72', 'Hayden', 'Brock', 'F', 'paid'),
#  ('51', 'Maia', 'Burke', 'F', 'free'),
#  ('32', 'Lily', 'Burns', 'F', 'free'),
#  ('90', 'Andrea', 'Butler', 'F', 'free'),
#  ('64', 'Hannah', 'Calhoun', 'F', 'free'),
#  ('27', 'Carlos', 'Carter', 'M', 'free'),
#  ('94', 'Noah', 'Chavez', 'M', 'free'),
#  ('41', 'Brayden', 'Clark', 'M', 'free'),
#  ('81', 'Sienna', 'Colon', 'F', 'free'),
#  ('54', 'Kaleb', 'Cook', 'M', 'free'),
#  ('59', 'Lily', 'Cooper', 'F', 'free'),
#  ('10', 'Sylvie', 'Cruz', 'F', 'free'),
#  ('49', 'Chloe', 'Cuevas', 'F', 'free'),
# ...

# %%
# %sql SELECT * FROM songs order by title;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 71 rows affected.
# [('SOFFKZS12AB017F194', 'A Higher Place (Album Version)', 'ARBEBBY1187B9B43DB', 1994, 236.173),
#  ('SODREIN12A58A7F2E5', 'A Whiter Shade Of Pale (Live @ Fillmore West)', 'ARLTWXK1187FB5A3F8', 0, 326.008),
#  ('SOXVLOJ12AB0189215', 'Amor De Cabaret', 'ARKRRTF1187B9984DA', 0, 177.475),
#  ('SORAMLE12AB017C8B0', 'Auguri Cha Cha', 'ARHHO3O1187B989413', 0, 191.843),
#  ('SOZHPGD12A8C1394FE', 'Baby Come To Me', 'AR9AWNF1187B9AB0B4', 0, 236.93),
#  ('SOTUKVB12AB0181477', 'Blessed Assurance', 'AR7ZKHQ1187B98DD73', 1993, 270.602),
#  ('SOWTBJW12AC468AC6E', 'Broken-Down Merry-Go-Round', 'ARQGYP71187FB44566', 0, 151.849),
#  ('SOXLBJT12A8C140925', 'Caught In A Dream', 'ARYKCQI1187FB3B18F', 2004, 290.298),
#  ('SOINLJW12A8C13314C', 'City Slickers', 'AR8IEZO1187B99055E', 2008, 149.864),
#  ('SOQOTLQ12AB01868D0', 'Clementina Santafè', 'ARGCY1Y1187B9A4FA5', 0, 153.338),
# ...

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARD0S291187B9B7BF5', 'Rated R', 'Ohio', nan, nan),
#  ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', 35.21962, -80.01955),
#  ('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', nan, nan),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', nan, nan),
#  ('ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', nan, nan)]

# %%
# %sql Select * from songplays where song_id != 'None';
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('483', datetime.datetime(2018, 11, 21, 21, 56, 47, 796000), '15', 'paid', 'SOZCTXZ12AB0182364', 'AR5KOSW1187FB35FF4', '818', 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')]

# %%
#SOZCTXZ12AB0182364 	Setanta matins 	AR5KOSW1187FB35FF4 	0 	269.583 	AR5KOSW1187FB35FF4 	Elena 	D

# %%
# %sql Select song_id, artist_id FROM (SELECT artists.artist_id, songs.song_id, artists.name, songs.title, songs.duration FROM songs INNER JOIN artists ON songs.artist_id = artists.artist_id) as songs_played
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 104 rows affected.
# [('SOMJBYD12A6D4F8557', 'ARD0S291187B9B7BF5'),
#  ('SOQHXMF12AB0182363', 'ARGSJW91187B9B1D6B'),
#  ('SOQHXMF12AB0182363', 'ARGSJW91187B9B1D6B'),
#  ('SONHOTT12A8C13493C', 'AR7G5I41187FB4CE6C'),
#  ('SOUDSGM12AC9618304', 'ARNTLGG11E2835DDB9'),
#  ('SOUDSGM12AC9618304', 'ARNTLGG11E2835DDB9'),
#  ('SOYMRWW12A6D4FAB14', 'ARKFYS91187B98E58F'),
#  ('SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1'),
#  ('SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1'),
#  ('SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1'),
#  ('SOCIWDW12A8C13D406', 'ARMJAGH1187FB546F3'),
#  ('SOCIWDW12A8C13D406', 'ARMJAGH1187FB546F3'),
#  ('SOHKNRJ12A6701D1F8', 'AR10USD1187B99F3F1'),
#  ('SOHKNRJ12A6701D1F8', 'AR10USD1187B99F3F1'),
#  ('SOFSOCN12A8C143F5D', 'ARXR32B1187FB57099'),
#  ('SOFSOCN12A8C143F5D', 'ARXR32B1187FB57099'),
#  ('SOXVLOJ12AB0189215', 'ARKRRTF1187B9984DA'),
#  ('SOXVLOJ12AB0189215', 'ARKRRTF1187B9984DA'),
# ...

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(2018, 11, 22, 0, 3, 52, 796000), 0, 22, 47, 11, 2018, '3'),
#  (datetime.datetime(2018, 11, 22, 0, 9, 10, 796000), 0, 22, 47, 11, 2018, '3'),
#  (datetime.datetime(2018, 11, 22, 0, 12, 6, 796000), 0, 22, 47, 11, 2018, '3'),
#  (datetime.datetime(2018, 11, 22, 0, 15, 41, 796000), 0, 22, 47, 11, 2018, '3'),
#  (datetime.datetime(2018, 11, 22, 0, 23, 40, 796000), 0, 22, 47, 11, 2018, '3')]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql select * from songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('0', datetime.datetime(2018, 11, 22, 0, 3, 52, 796000), '15', 'paid', None, None, '818', 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  ('1', datetime.datetime(2018, 11, 22, 0, 9, 10, 796000), '15', 'paid', None, None, '818', 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  ('2', datetime.datetime(2018, 11, 22, 0, 12, 6, 796000), '15', 'paid', None, None, '818', 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
# ...
